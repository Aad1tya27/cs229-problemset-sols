# %%
import numpy as np

# %%
import util

# %%
from linear_model import LinearModel

# %%
from p01b_logreg import main

# %%
main
# Out:
# <function p01b_logreg.main(train_path, eval_path, pred_path)>

# %%
main("../data/ds1_train.csv","../data/ds1_valid.csv", "../pred/1b.csv")
# Out:
# Accuracy of model is:  90.0
